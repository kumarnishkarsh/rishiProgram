# %%
# Program to play a game of maths in which you will get addition sums and you have to write correct answer.  
# By : Nishkarsh Kumar 31st March 2020
import random

a = 0
print("There are two levels : Level 1 and Level 2")
print(" ")
print("Level 2 has 1 question only.")
print(" ")
print("Level 1 has simple single number addition.")
print("Level 2 has 3-4 digit additions.")
print(" ")
print("Type '1' for Level 1 and '2'for level 2.")
print(" ")
level = input("Which level do you want ?") 
if level == "1":
    for i in range(1,6):
     
        num1 = random.randrange(0, 10)
        num2 = random.randrange(0, 10)
    
        ans = input("Expression :" + str(num1) + "+" + str(num2) + "  " + "Please enter the answer :")
    
        ans = int(ans)
        realans = num1 + num2  
        print("Correct answer is :" , realans)

        if ans == realans:
            a = a + 1
            print("Good")
            print("Marks :" ,  a)
        else:
            a = a - 1
            print("Wrong") 
            print("Marks :" , a)     
else :  
    
    for loop5 in range(1,6):
     
          num11 = random.randrange(99, 1000)
          num22 = random.randrange(99, 1000)
    
    ans2 = input("Expression :" + str(num11) + "+" + str(num22) + "  " + "Please enter the answer :")
    
    ans2 = int(ans2)
    realans2 = num11 + num22  
    print("Correct answer is :" , realans2)

    if ans2 == realans2 :
        a = a + 1
        print("Good")
        print("Marks :" ,  a)
    else :
        a = a - 1
        print("Wrong") 
        print("Marks :" , a)
        print(" ")
# Out:
# There are two levels : Level 1 and Level 2
#
# Level 2 has 1 question only.
#
# Level 1 has simple single number addition.
# Level 2 has 3-4 digit additions.
#
# Type '1' for Level 1 and '2'for level 2.
#
# Which level do you want ?1
# Expression :9+0  Please enter the answer :9
# Correct answer is : 9
# Good
# Marks : 1
# Expression :5+0  Please enter the answer :5
# Correct answer is : 5
# Good
# Marks : 2
# Expression :0+1  Please enter the answer :1
# Correct answer is : 1
# Good
# Marks : 3
# Expression :3+6  Please enter the answer :9
# Correct answer is : 9
# Good
# Marks : 4
# Expression :4+3  Please enter the answer :7
# Correct answer is : 7
# Good
# Marks : 5
