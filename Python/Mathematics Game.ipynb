# %%
#This program is to paly the game ob basic aritmetic operations : 4th April 2020 By Nishkarsh Kumar
import random

def take_name() :
      global name
      name = input("What is your name ?")

def greet_user() :
      print("Hello , " , name)
        
def game_rules() :
      print("GAME RULES :")
      print("------------------------")
      print("1.    Each level will have 5 questions.")
      print("2.    There are negative marking for one wrong answer")
      print("3.    This game has normal mathematical questions.")
      print("4.    There is 1 mark for each correct answer.")
      print("-------------------------")   
def show_results() :            
      print("-------------------------")
      print("      TEST RESULTS       ")
      print("-------------------------")
      print("You scored" , a , "out of" , questions)        
global a        
a = 0 
take_name()
greet_user()
game_rules()
opera = input("Which operator do you want : '/'  '*'  '+'  '-' : ")

if opera == "+":
  questions = 5
  complexity = 10
  levelnum = 1
  
  def play() :
      global levelnum
      global complexity
      global questions
      print("-------------------------")
      print("This is your Level " , levelnum)
      for i in range(1,6):
          num1 = random.randrange(0, complexity*levelnum)
          num2 = random.randrange(0, complexity*levelnum)
          
          print("-------------------------")
          ans = input("Q.  Solve the Expression :" + str(num1) + "+" + str(num2) + "  " + "Please enter the answer :")
          print("-------------------------")

          ans = int(ans)
          realans = num1 + num2  
          print("Correct answer is :" , realans)
          global a

          if ans == realans:
              a = a + 1
              print("Good")
              print("Marks :" ,  a)
          else :
              a = a - 1
              print("Wrong") 
              print("----------------------------")
      passing_marks = levelnum * 3
      if a >= passing_marks:
       print("!  CONGRATULATIONS  !" , name , "you qualified for level" , levelnum+1)
       print("----------------------")
       greet_user()
       show_results()
       levelnum = levelnum + 1
       questions = questions + 5
       play()
      else:
       print("Oh no!" , name , "you have not qualified for level" , levelnum+1)
       show_results()
       print("Please restart the game again.")   
       #print("Marks :" , a)
       print("Level : Fail")
  play()     

elif opera == "/":
  questions = 5
  complexity = 10
  levelnum = 1
  print("Please enter the answer in round till first decimal.")
  def play() :
      global levelnum
      global complexity
      global questions
      print("This is your Level " , levelnum)
      for i in range(1,6):
          num1 = random.randrange(0, complexity*levelnum)
          num2 = random.randrange(0, complexity*levelnum)
   
          ans = input("Q.  Solve the Expression :" + str(num1) + "/" + str(num2) + "  " + "Please enter the answer :")

          ans = float(ans)
          ans = round(ans,1)
          realans = num1 / num2 
          realans = float(realans)
          realans = round(realans,1) 
          print("Correct answer is :" , realans)
          global a

          if ans == realans:
              a = a + 1
              print("Good")
              print("Marks :" ,  a)
          else :
              a = a - 1
              print("Wrong") 
              print("Marks :" , a)
              print(" ")
      passing_marks = levelnum * 3
      if a >= passing_marks:
       print("!  CONGRATULATIONS  !" , name , "you qualified for level" , levelnum+1)
       print("----------------------")
       greet_user()
       show_results()
       levelnum = levelnum + 1
       questions = questions + 5
       play()
      else:
       print("Oh no!" , name , "you have not qualified for level" , levelnum+1)
       show_results()
       print("Please restart the game again.")   
       #print("Marks :" , a)
       print("Level : Fail")
  play()     
elif opera == "*":
  questions = 5
  complexity = 10
  levelnum = 1
      
  def play() :
      global levelnum
      global complexity
      global questions
      print("This is your Level " , levelnum)
      for i in range(1,6):
          num1 = random.randrange(0, complexity*levelnum)
          num2 = random.randrange(0, complexity*levelnum)
   
          ans = input("Q.  Solve the Expression :" + str(num1) + "*" + str(num2) + "  " + "Please enter the answer :")

          ans = int(ans)
          realans = num1 * num2  
          print("Correct answer is :" , realans)
          global a

          if ans == realans:
              a = a + 1
              print("Good")
              print("Marks :" ,  a)
          else :
              a = a - 1
              print("Wrong") 
              print("Marks :" , a)
              print(" ")
      passing_marks = levelnum * 3
      if a >= passing_marks:
       print("!  CONGRATULATIONS  !" , name , "you qualified for level" , levelnum+1)
       print("----------------------")
       greet_user()
       show_results()
       levelnum = levelnum + 1
       questions = questions + 5
       play()
      else:
       print("Oh no!" , name , "you have not qualified for level" , levelnum+1)
       show_results()
       print("Please restart the game again.")   
       #print("Marks :" , a)
       print("Level : Fail")
  play()     
else:  
  questions = 5
  complexity = 10
  levelnum = 1
  greet_user()
  def play() :
      global levelnum
      global complexity
      global questions
      print("This is your Level " , levelnum)
      for i in range(1,6):
          num1 = random.randrange(0, complexity*levelnum)
          num2 = random.randrange(0, complexity*levelnum)
          if num1 > num2:
            larger = num1
            smaller = num2
          else:
            larger = num2
            smaller = num1
          ans = input("Q.  Solve the Expression :" + str(larger) + "-" + str(smaller) + "  " + "Please enter the answer :")

          ans = int(ans)
          realans = larger - smaller  
          print("Correct answer is :" , realans)
          global a

          if ans == realans:
              a = a + 1
              print("Good")
              print("Marks :" ,  a)
          else :
              a = a - 1
              print("Wrong") 
              print("Marks :" , a)
              print(" ")
      passing_marks = levelnum * 3
      if a >= passing_marks:
       print("!  CONGRATULATIONS  !" , name , "you qualified for level" , levelnum+1)
       print("----------------------")
       greet_user()
       show_results()
       levelnum = levelnum + 1
       questions = questions + 5
       play()
      else:
       print("Oh no!" , name , "you have not qualified for level" , levelnum+1)
       show_results()
       print("Please restart the game again.")   
       #print("Marks :" , a)
       print("Level : Fail")
  play()
# Out:
# What is your name ?Rishi
# Hello ,  Rishi
# GAME RULES :
# ------------------------
# 1.    Each level will have 5 questions.
# 2.    There are negative marking for one wrong answer
# 3.    This game has normal mathematical questions.
# 4.    There is 1 mark for each correct answer.
# -------------------------
# Which operator do you want : '/'  '*'  '+'  '-' : +
# -------------------------
# This is your Level  1
# -------------------------
# Q.  Solve the Expression :5+5  Please enter the answer :10
# -------------------------
# Correct answer is : 10
# Good
# Marks : 1
# -------------------------
# Q.  Solve the Expression :1+9  Please enter the answer :10
# -------------------------
# Correct answer is : 10
# Good
# Marks : 2
# -------------------------
# Q.  Solve the Expression :9+0  Please enter the answer :9
# -------------------------
# Correct answer is : 9
# Good
# Marks : 3
# -------------------------
# Q.  Solve the Expression :5+4  Please enter the answer :9
# ...
